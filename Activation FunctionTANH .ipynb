# %%
import numpy as np

# %%
x = np.array([-3, -2, -1, 0, 1, 2, 3])

# %%
output = np.tanh(x)
print("Input Values:")
print(x)
print("\nTanh Output:")
print(output)
# Out:
# Input Values:
# [-3 -2 -1  0  1  2  3]
#
# Tanh Output:
# [-0.99505475 -0.96402758 -0.76159416  0.          0.76159416  0.96402758
#   0.99505475]
